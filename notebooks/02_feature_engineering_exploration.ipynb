# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path
from scipy.stats import ttest_ind
from src.feature_engineering import create_features

# %%
customers = pd.read_csv(
    "../data/raw/customers.csv"
)

df = create_features(customers)

print(df.head())
print(df.columns.tolist())
# Out:
#    customer_id  age   income  tenure_years  account_balance  savings_balance  \
# 0       100001   39  52389.0             7          2883.53         30240.78
# 1       100002   23  18000.0             5         28623.86         43789.16
# 2       100003   44  23315.0             6          7406.25         42273.09
# 3       100004   46  27029.0             1         17038.56          1134.71
# 4       100005   28  41283.0            13          6008.05         31998.56
#
#    monthly_app_logins  monthly_transactions  complaints  \
# 0                   8                    21           0
# 1                   9                    12           0
# 2                  11                    22           1
# 3                  15                    12           0
# 4                  13                    17           0
#
#    customer_satisfaction  balance_change_pct  churned  total_balance  \
# 0                   10.0              -10.80        0       33124.31
# 1                    9.0                6.63        1       72413.02
# 2                    8.2               11.72        0       49679.34
# 3                    6.4               21.71        0       18173.27
# 4                    5.8                0.41        0       38006.61
#
#    savings_ratio  transactions_per_login  has_complaint  low_engagement  \
# 0       0.912948                2.625000              0               0
# 1       0.604714                1.333333              0               0
# 2       0.850919                2.000000              1               0
# 3       0.062438                0.800000              0               0
# 4       0.841921                1.307692              0               0
#
#    balance_declining
# 0                  1
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ['customer_id', 'age', 'income', 'tenure_years', 'account_balance', 'savings_balance', 'monthly_app_logins', 'monthly_transactions', 'complaints', 'customer_satisfaction', 'balance_change_pct', 'churned', 'total_balance', 'savings_ratio', 'transactions_per_login', 'has_complaint', 'low_engagement', 'balance_declining']

# %%
print(df[
    [
        "total_balance",
        "savings_ratio",
        "transactions_per_login",
        "has_complaint",
        "low_engagement",
        "balance_declining"
    ]
].describe())

print(df["has_complaint"].value_counts())
print(df["low_engagement"].value_counts())
print(df["balance_declining"].value_counts())
# Out:
#        total_balance  savings_ratio  transactions_per_login  has_complaint  \
# count   20000.000000   19412.000000            20000.000000   20000.000000
# mean    25905.287013       0.553344                1.644799       0.331000
# std     17401.796103       0.352586                0.746450       0.470585
# min         0.000000       0.000000                0.076923       0.000000
# 25%     12050.647500       0.237339                1.157895       0.000000
# 50%     23330.865000       0.654705                1.500000       0.000000
# 75%     37399.122500       0.838034                2.000000       1.000000
# max    114042.630000       1.000000               20.000000       1.000000
#
#        low_engagement  balance_declining
# count      20000.0000       20000.000000
# mean           0.0001           0.497900
# std            0.0100           0.500008
# min            0.0000           0.000000
# 25%            0.0000           0.000000
# 50%            0.0000           0.000000
# 75%            0.0000           1.000000
# max            1.0000           1.000000
# has_complaint
# 0    13380
# 1     6620
# Name: count, dtype: int64
# low_engagement
# 0    19998
# 1        2
# Name: count, dtype: int64
# balance_declining
# 0    10042
# 1     9958
# Name: count, dtype: int64
